# %% [markdown]
# ### NumPy, Pandas, Matplotlib

# %%
# %matplotlib inline

import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt

# %% [markdown]
# #### NumPy

# %%
np.pi   
np.sin(60)
np.cos(90)
np.log10(100)
np.exp(5)
# Out:
# 148.4131591025766

# %%
def f(x):
    return np.sin(x)

def g(x):
    return np.cos(x)

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 

# %matplotlib inline

x = np.linspace(-5, 5, 25)

y = f(x)
t = g(x)

plt.plot(x, y)
plt.plot(x, t)

# plt.figure()
plt.show()

 
print('Peter Zorve')
# Out:
# Peter Zorve

# %%
import matplotlib
print(matplotlib.get_backend())
print(matplotlib.__file__)
print(matplotlib.__version__)
# Out:
# module://matplotlib_inline.backend_inline
# c:\Users\zorve\anaconda3\envs\deeplearning\lib\site-packages\matplotlib\__init__.py
# 3.6.2

# %%
plt.bar(x, y)
plt.show()

# %%
plt.scatter(x, y)
plt.show()

# %% [markdown]
# #### Pandas

# %%
path = 'C:/Users/zorve/OneDrive/Desktop/github_upload/3.__NumPy_Pandas_Matplotlib/seeds.csv'
data = pd.read_csv(path)
data
# Out:
#       area  perimeter  compactness  length  width  asymmetry_coefficient  \
# 0    15.26      14.84       0.8710   5.763  3.312                  2.221
# 1    14.88      14.57       0.8811   5.554  3.333                  1.018
# 2    14.29      14.09       0.9050   5.291  3.337                  2.699
# 3    13.84      13.94       0.8955   5.324  3.379                  2.259
# 4    16.14      14.99       0.9034   5.658  3.562                  1.355
# ..     ...        ...          ...     ...    ...                    ...
# 205  12.19      13.20       0.8783   5.137  2.981                  3.631
# 206  11.23      12.88       0.8511   5.140  2.795                  4.325
# 207  13.20      13.66       0.8883   5.236  3.232                  8.315
# 208  11.84      13.21       0.8521   5.175  2.836                  3.598
# 209  12.30      13.34       0.8684   5.243  2.974                  5.637
#
#      groove_length   grain_variety
# 0            5.220      Kama wheat
# 1            4.956      Kama wheat
# 2            4.825      Kama wheat
# 3            4.805      Kama wheat
# 4            5.175      Kama wheat
# ..             ...             ...
# 205          4.870  Canadian wheat
# 206          5.003  Canadian wheat
# 207          5.056  Canadian wheat
# 208          5.044  Canadian wheat
# 209          5.063  Canadian wheat
#
# [210 rows x 8 columns]

# %%
data.head(3)
# Out:
#     area  perimeter  compactness  length  width  asymmetry_coefficient  \
# 0  15.26      14.84       0.8710   5.763  3.312                  2.221
# 1  14.88      14.57       0.8811   5.554  3.333                  1.018
# 2  14.29      14.09       0.9050   5.291  3.337                  2.699
#
#    groove_length grain_variety
# 0          5.220    Kama wheat
# 1          4.956    Kama wheat
# 2          4.825    Kama wheat

# %%
data.tail(3)
# Out:
#       area  perimeter  compactness  length  width  asymmetry_coefficient  \
# 207  13.20      13.66       0.8883   5.236  3.232                  8.315
# 208  11.84      13.21       0.8521   5.175  2.836                  3.598
# 209  12.30      13.34       0.8684   5.243  2.974                  5.637
#
#      groove_length   grain_variety
# 207          5.056  Canadian wheat
# 208          5.044  Canadian wheat
# 209          5.063  Canadian wheat

# %%
data.area
data['area']
# Out:
# 0      15.26
# 1      14.88
# 2      14.29
# 3      13.84
# 4      16.14
#        ...
# 205    12.19
# 206    11.23
# 207    13.20
# 208    11.84
# 209    12.30
# Name: area, Length: 210, dtype: float64

# %%
columns = ['area', 'perimeter', 'compactness', 'length',	'width']
# data[columns]
seed_property = data[['area', 'perimeter', 'compactness', 'length',	'width']]

# %%
data['grain_variety'].value_counts()
# Out:
# Rosa wheat         70
# Canadian wheat     70
# Kama wheat         69
# Kama wheat          1
# Name: grain_variety, dtype: int64

# %%
seed_property.head(3)
# Out:
#     area  perimeter  compactness  length  width
# 0  15.26      14.84       0.8710   5.763  3.312
# 1  14.88      14.57       0.8811   5.554  3.333
# 2  14.29      14.09       0.9050   5.291  3.337

# %%
seed_property.columns
# Out:
# Index(['area', 'perimeter', 'compactness', 'length', 'width'], dtype='object')

# %%
data.columns
# Out:
# Index(['area', 'perimeter', 'compactness', 'length', 'width',
#        'asymmetry_coefficient', 'groove_length', 'grain_variety'],
#       dtype='object')

# %%
seed_property.head(3)
# Out:
#     area  perimeter  compactness  length  width
# 0  15.26      14.84       0.8710   5.763  3.312
# 1  14.88      14.57       0.8811   5.554  3.333
# 2  14.29      14.09       0.9050   5.291  3.337

# %%
seed_property['ratio'] = seed_property['length'] / seed_property['width']
seed_property['ratio']
# Out:
# C:\Users\zorve\AppData\Local\Temp\ipykernel_26360\3666909737.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   seed_property['ratio'] = seed_property['length'] / seed_property['width']
# 0      1.740036
# 1      1.666367
# 2      1.585556
# 3      1.575614
# 4      1.588433
#          ...
# 205    1.723247
# 206    1.838998
# 207    1.620050
# 208    1.824753
# 209    1.762946
# Name: ratio, Length: 210, dtype: float64

# %%
# print(seed_property)
seed_property
# Out:
#       area  perimeter  compactness  length  width     ratio
# 0    15.26      14.84       0.8710   5.763  3.312  1.740036
# 1    14.88      14.57       0.8811   5.554  3.333  1.666367
# 2    14.29      14.09       0.9050   5.291  3.337  1.585556
# 3    13.84      13.94       0.8955   5.324  3.379  1.575614
# 4    16.14      14.99       0.9034   5.658  3.562  1.588433
# ..     ...        ...          ...     ...    ...       ...
# 205  12.19      13.20       0.8783   5.137  2.981  1.723247
# 206  11.23      12.88       0.8511   5.140  2.795  1.838998
# 207  13.20      13.66       0.8883   5.236  3.232  1.620050
# 208  11.84      13.21       0.8521   5.175  2.836  1.824753
# 209  12.30      13.34       0.8684   5.243  2.974  1.762946
#
# [210 rows x 6 columns]

# %%
seed_property.drop('perimeter', axis=1)
# Out:
#       area  compactness  length  width     ratio
# 0    15.26       0.8710   5.763  3.312  1.740036
# 1    14.88       0.8811   5.554  3.333  1.666367
# 2    14.29       0.9050   5.291  3.337  1.585556
# 3    13.84       0.8955   5.324  3.379  1.575614
# 4    16.14       0.9034   5.658  3.562  1.588433
# ..     ...          ...     ...    ...       ...
# 205  12.19       0.8783   5.137  2.981  1.723247
# 206  11.23       0.8511   5.140  2.795  1.838998
# 207  13.20       0.8883   5.236  3.232  1.620050
# 208  11.84       0.8521   5.175  2.836  1.824753
# 209  12.30       0.8684   5.243  2.974  1.762946
#
# [210 rows x 5 columns]

# %%
seed_property.drop('ratio', axis=1)
# Out:
#       area  perimeter  compactness  length  width
# 0    15.26      14.84       0.8710   5.763  3.312
# 1    14.88      14.57       0.8811   5.554  3.333
# 2    14.29      14.09       0.9050   5.291  3.337
# 3    13.84      13.94       0.8955   5.324  3.379
# 4    16.14      14.99       0.9034   5.658  3.562
# ..     ...        ...          ...     ...    ...
# 205  12.19      13.20       0.8783   5.137  2.981
# 206  11.23      12.88       0.8511   5.140  2.795
# 207  13.20      13.66       0.8883   5.236  3.232
# 208  11.84      13.21       0.8521   5.175  2.836
# 209  12.30      13.34       0.8684   5.243  2.974
#
# [210 rows x 5 columns]

# %%
data.drop_duplicates()
data.dropna()
# Out:
#       area  perimeter  compactness  length  width  asymmetry_coefficient  \
# 0    15.26      14.84       0.8710   5.763  3.312                  2.221
# 1    14.88      14.57       0.8811   5.554  3.333                  1.018
# 2    14.29      14.09       0.9050   5.291  3.337                  2.699
# 3    13.84      13.94       0.8955   5.324  3.379                  2.259
# 4    16.14      14.99       0.9034   5.658  3.562                  1.355
# ..     ...        ...          ...     ...    ...                    ...
# 205  12.19      13.20       0.8783   5.137  2.981                  3.631
# 206  11.23      12.88       0.8511   5.140  2.795                  4.325
# 207  13.20      13.66       0.8883   5.236  3.232                  8.315
# 208  11.84      13.21       0.8521   5.175  2.836                  3.598
# 209  12.30      13.34       0.8684   5.243  2.974                  5.637
#
#      groove_length   grain_variety
# 0            5.220      Kama wheat
# 1            4.956      Kama wheat
# 2            4.825      Kama wheat
# 3            4.805      Kama wheat
# 4            5.175      Kama wheat
# ..             ...             ...
# 205          4.870  Canadian wheat
# 206          5.003  Canadian wheat
# 207          5.056  Canadian wheat
# 208          5.044  Canadian wheat
# 209          5.063  Canadian wheat
#
# [210 rows x 8 columns]

# %% [markdown]
# #### Matplotlib

# %%
x = np.linspace(-10, 10, 10000)
# print(x)

def f(x):
    return np.cos(x)

def g(x):
    return np.sin(x)

# %%
plt.plot(x, f(x))
plt.plot(x, g(x))
plt.ylabel('sin(x) or cos(x)')
plt.xlabel('x')
# Out:
# Text(0.5, 0, 'x')

# %%
x = np.linspace(0, 10, 10)
plt.bar(x, 2*x)
# Out:
# <BarContainer object of 10 artists>

# %%
x = np.linspace(-10, 10, 10000)
# print(x)

def f(x):
    return np.cos(x)

def g(x):
    return np.sin(x)

plt.bar(x, f(x))
# Out:
# <BarContainer object of 10000 artists>

# %%
x = np.linspace(-10, 10, 30)

def f(x):
    return np.cos(x)

plt.scatter(x, f(x))

# %%
import os 

folder_path = "C:/Users/zorve/OneDrive/Desktop/github_upload/3.__NumPy_Pandas_Matplotlib/data"
file_path =   "C:/Users/zorve/OneDrive/Desktop/github_upload/3.__NumPy_Pandas_Matplotlib/data/"

# 'C:/Users/zorve/OneDrive/Desktop/github_upload/3.__NumPy_Pandas_Matplotlib/data'

for file in os.listdir(folder_path):
    files = file_path + file

    with open(files, 'r') as f: 
        lines = f.readlines()
        print(lines)
